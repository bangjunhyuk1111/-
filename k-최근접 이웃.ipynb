# %% [markdown]
# <a href="https://colab.research.google.com/github/bangjunhyuk1111/-/blob/main/k-%EC%B5%9C%EA%B7%BC%EC%A0%91%20%EC%9D%B4%EC%9B%83.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# k-최근접 이웃
#
# 지도학습(정답 데이터 필요)
# 사전에 정답 데이터들을 통해 산점도를 만들고,
# 새로 입력되는 데이터를 산점도 위에 표시 했을때
# 그 주변에 많이 해당되어 있는 정답 데이터에 따라 입력된 데이터가 무엇인지 판단하다.
